# %%
import gc;

# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path="../.env")
# Out:
# True

# %%
import pandas as pd
import os

# %%
from langsmith_ragas_composite_rankers import analyze_retrievers

# %%
results = analyze_retrievers('langsmith_retriever_raw_stats.csv', 'ragas_retriever_raw_stats.csv')

# %% [markdown]
# ## Final outcome of the LangSmith and Ragas Evaluators (combined)

# %%
results['category_leaders']
# Out:
#          Category               Retriever  Score
# 0    Overall Best                    Bm25   73.1
# 1  Quality Leader                Ensemble   81.6
# 2  Most Efficient  Contextual Compression   74.2
# 3   Most Reliable                Ensemble   94.2

# %%
results['rankings'].sort_values(by='composite_score', ascending=False)
# Out:
#    rank               retriever  composite_score  quality_score  \
# 1     2  Contextual Compression             74.4           74.0
# 4     5         Parent Document             74.4           78.5
# 2     3                Ensemble             74.3           81.6
# 0     1                    Bm25             73.1           76.9
# 3     4                   Naive             70.6           78.1
# 5     6             Multi Query             69.6           81.1
#
#    efficiency_score  reliability_score
# 1              74.2               75.9
# 4              68.3               73.3
# 2              48.9               94.2
# 0              68.0               71.2
# 3              49.5               83.3
# 5              53.4               65.1

# %%
results['detailed_metrics'].sort_values(by='composite_score', ascending=False)
# Out:
#                 retriever  ls_helpfulness  ls_correctness  ragas_recall  \
# 1  Contextual Compression           0.800           0.900      0.639524
# 4         Parent Document           0.833           0.833      0.898095
# 2                Ensemble           0.900           0.867      0.931429
# 0                    Bm25           0.667           0.900      0.856190
# 3                   Naive           0.900           0.833      0.758810
# 5             Multi Query           0.867           0.828      0.887381
#
#    ragas_faithfulness  ragas_correctness  avg_cost  composite_score
# 1            0.803765           0.472222  0.006245             74.4
# 4            0.895017           0.441000  0.007683             74.4
# 2            0.878024           0.414000  0.012366             74.3
# 0            0.867977           0.445000  0.007746             73.1
# 3            0.840723           0.454000  0.012239             70.6
# 5            0.915717           0.506000  0.011289             69.6

# %%
results['full_results'].sort_values(by='composite_score', ascending=False)
# Out:
#                 retriever  quality_score  efficiency_score  reliability_score  \
# 1  Contextual Compression           74.0              74.2               75.9
# 4         Parent Document           78.5              68.3               73.3
# 2                Ensemble           81.6              48.9               94.2
# 0                    Bm25           76.9              68.0               71.2
# 3                   Naive           78.1              49.5               83.3
# 5             Multi Query           81.1              53.4               65.1
#
#    composite_score  ls_helpfulness  ls_correctness  ragas_recall  \
# 1             74.4           0.800           0.900      0.639524
# 4             74.4           0.833           0.833      0.898095
# 2             74.3           0.900           0.867      0.931429
# 0             73.1           0.667           0.900      0.856190
# 3             70.6           0.900           0.833      0.758810
# 5             69.6           0.867           0.828      0.887381
#
#    ragas_faithfulness  ragas_correctness  avg_cost
# 1            0.803765           0.472222  0.006245
# 4            0.895017           0.441000  0.007683
# 2            0.878024           0.414000  0.012366
# 0            0.867977           0.445000  0.007746
# 3            0.840723           0.454000  0.012239
# 5            0.915717           0.506000  0.011289
